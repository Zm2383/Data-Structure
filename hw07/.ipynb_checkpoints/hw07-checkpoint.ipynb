# %% [markdown]
# # provide a link to your TestPyPi package and the repo of your package

# %% [markdown]
# ## https://test.pypi.org/project/cipher-zm2383/

# %% [markdown]
# ## repo of my package:https://github.com/QMSS-G5072-2021/cipher_Zhenwei_Ma

# %% [markdown]
# # directly install your package from TestPyPi

# %%
# !pip install -i https://test.pypi.org/simple/ cipher-zm2383
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...

# %% [markdown]
# import your package

# %%
from cipher_zm2383 import cipher_zm2383

# %% [markdown]
# run the cipher function for an example

# %%
text = "Math."
shift = 1
cipher_zm2383.cipher(text, shift)
# Out:
# 'Nbui.'

# %% [markdown]
# # show the output of help

# %%
help(cipher_zm2383)##I wrote it in the. Py file, but it can't be displayed.
# Out:
# Help on module cipher_zm2383.cipher_zm2383 in cipher_zm2383:
#
# NAME
#     cipher_zm2383.cipher_zm2383
#
# FUNCTIONS
#     cipher(text, shift, encrypt=True)
#
# FILE
#     /Users/apple/opt/anaconda3/lib/python3.8/site-packages/cipher_zm2383/cipher_zm2383.py

# %% [markdown]
# ![WechatIMG1205.jpeg](attachment:WechatIMG1205.jpeg)

# %%
help(cipher_zm2383.cipher)
# Out:
# Help on function cipher in module cipher_zm2383.cipher_zm2383:
#
# cipher(text, shift, encrypt=True)
